# %% [markdown]
# <a href="https://colab.research.google.com/github/NarenneraN/TimeSeries/blob/main/08_ACF_Plot_To_Find_Seasonality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv')

# %%
autocorrelation_plot(df['value'].tolist())
