# %% [markdown]
# <a href="https://colab.research.google.com/github/NarenneraN/TimeSeries/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
df = pd.read_csv("combined_data.csv")

# %%
from random import randint
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset_description = df.describe()
dataset_description
# Out:
#        Machine ID  Time Cycle  Temperature    Vibration        Sound  \
# count  696.000000  696.000000   696.000000   696.000000   696.000000
# mean     9.820402   26.977011    31.167251  3934.812357   205.435303
# std      5.522817   19.889176     2.008357   340.534119   170.016005
# min      1.000000    1.000000    28.000928  1547.408772    92.920432
# 25%      6.000000   11.000000    29.664128  3988.243708   117.930280
# 50%      9.000000   23.000000    31.844390  4058.787518   141.224703
# 75%     13.000000   37.250000    32.543554  4081.663233   201.006333
# max     22.000000   85.000000    39.741542  4094.922499  1042.834192
#
#                Ax          Ay          Az            Gx          Gy  \
# count  696.000000  696.000000  696.000000  6.960000e+02  696.000000
# mean    -0.635329   -0.158060    9.380920 -6.000000e-02    0.029700
# std      0.002934    0.003957    0.011610  6.943884e-18    0.005648
# min     -0.640000   -0.160000    9.360196 -6.000000e-02    0.020015
# ...

# %%
features = np.array(df.columns)

# %%
features=features[2:len(features)-1]
features
# Out:
# array(['Temperature', 'Vibration', 'Sound', 'Ax', 'Ay', 'Az', 'Gx', 'Gy',
#        'Gz', 'Fault'], dtype=object)

# %%
df_plot = df.copy()[features]
df_corr = df_plot.corr(method='pearson')
fig, ax = plt.subplots(figsize=(15,15))
axes = sns.heatmap(df_corr, linewidths=.2, )
# Out:
# <ipython-input-14-518631e3e0f1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df_plot.corr(method='pearson')

# %%
metadata = ['Machine ID', 'Time Cycle']
df_plot = df.copy()
df_plot = df_plot.sort_values(metadata)
#print(df_plot)
graph = sns.PairGrid(data=df_plot, x_vars="RUL", y_vars=features, hue="Machine ID", height=4, aspect=6,)
graph = graph.map(plt.plot, alpha=0.5)
graph = graph.set(xlim=(df_plot['RUL'].max(),df_plot['RUL'].min()))
graph = graph.add_legend()

# %%
import random
number_of_engine_no = len(df['Machine ID'].drop_duplicates())
number_of_engine_no
# Out:
# 17

# %%
tot_mach=df['Machine ID'].drop_duplicates().values
tot_mach
# Out:
# array([20,  1,  4, 11, 14, 22,  3,  7, 12,  8,  2,  9, 21, 13,  5, 10,  6])

# %%
engine_no_train = np.random.choice(tot_mach, size=12, replace=False)
engine_no_train
# Out:
# array([ 6, 21, 11, 12,  7, 10, 14, 13, 22,  4,  9, 20])

# %%
engine_no_val=[x for x in tot_mach if x not in set(engine_no_train)]
engine_no_val
# Out:
# [1, 3, 8, 2, 5]

# %%
df_eval=df.copy()

# %%
data_train = df[df['Machine ID'].isin(engine_no_train)]
#print(data_train)
data_val = df[df['Machine ID'].isin(engine_no_val)]

X_train, y_train = data_train[features], data_train['RUL'] 
#print(X_train,y_train)
X_val, y_val = data_val[features], data_val['RUL']
#print(X_val,y_val)
X_eval = df_eval[features]


X_all, y_all = df[features], df['RUL']
print(type(X_train),y_train)
# Out:
# <class 'pandas.core.frame.DataFrame'> 0      35
# 1      34
# 2      33
# 3      32
# 4      31
#        ..
# 691     5
# 692     4
# 693     3
# 694     2
# 695     1
# Name: RUL, Length: 533, dtype: int64
